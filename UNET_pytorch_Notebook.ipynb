# %% [markdown]
# ### Installing Dependencies

# %%
# !pip3 install torch==1.12.0
# !pip3 install torchvision==0.13.0
# !pip3 install numpy==1.21.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp37-cp37m-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 20 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.12.0) (4.1.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.12.0 which is incompatible.
# Successfully installed torch-1.12.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision==0.13.0
#   Downloading torchvision-0.13.0-cp37-cp37m-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 6.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision==0.13.0) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision==0.13.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.13.0) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.13.0) (7.1.2)
# Requirement already satisfied: torch==1.12.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.13.0) (1.12.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.13.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.13.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.13.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.13.0) (2022.6.15)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# Successfully installed torchvision-0.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy==1.21.6 in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %% [markdown]
# ### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch
# Out:
# /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch

# %% [markdown]
# ### Importing Libraries

# %%
import os
import argparse
import numpy as np
from skimage import io, transform
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import tifffile as tiff
from skimage.transform import resize
import torch
import torch.nn as nn
from torch import nn, optim, DoubleTensor
from torch import cuda
from torch.utils.data import DataLoader
from torch.utils.data.sampler import WeightedRandomSampler
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision import transforms, datasets
#from unet import UNet
from celldata import CellDataset
from metric import iou, pix_acc
from loss import Weighted_Cross_Entropy_Loss
from augmentation import (
    DoubleCompose, DoubleToTensor,
    DoubleHorizontalFlip, DoubleVerticalFlip, DoubleElasticTransform,
    GaussianNoise
)

# %% [markdown]
# ### Defining Variables

# %%
pretrained_model_path='/content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch/checkpoints'
data_dir='/content/drive/MyDrive/Colab_Notebooks/data/VNC'
epochs=50
lr=0.0001
batch_size=3
test_batch_size=3

# %% [markdown]
# ## Defining UNet model

# %%
class UNet(torch.nn.Module):

    def __init__(self, n_classes, batch_norm=True):
        """
        """
        self.name = 'UNet'
        self.n_classes = n_classes
        self.filter_sizes = [64, 128, 256, 512, 1024]
        self.n_block = len(self.filter_sizes)
        self.batch_norm = batch_norm
        # self.num_layers = [2, 2, 2, 2, 2]

        super(UNet, self).__init__()
        self.contract_blocks = self.contract()
        self.expand_blocks = self.expand()
        self.segment = nn.Conv2d(
            self.filter_sizes[0],
            self.n_classes,
            kernel_size=1
        )

    def forward(self, x):
        """Performs a forward pass through the network
        """
        xs = []
        for block in self.contract_blocks:
            new_x = block(x)
            xs.append(new_x)
            x = new_x

        for i, block in enumerate(self.expand_blocks):
            x = block['up'](x)
            k = self.n_block - i - 2
            x = self.concat(xs[k], x)
            x = block['conv'](x)

        y_pred = self.segment(x)

        return y_pred

    def concat(self, x, y):
        """Crop and concatenate two feature maps
        """
        dw = (x.size()[2] - y.size()[2]) // 2
        dh = (x.size()[3] - y.size()[2]) // 2
        x = x[:, :, dw:x.size()[2] - dw, dh:x.size()[3] - dh]
        return torch.cat((x, y), 1)

    def contract(self):
        """Define contraction block in U-Net
        """
        blocks = []
        old = 1
        for i, size in enumerate(self.filter_sizes):
            mpool = nn.MaxPool2d(kernel_size=2)
            conv1 = nn.Conv2d(old, size, kernel_size=3)
            conv2 = nn.Conv2d(size, size, kernel_size=3)
            relu = nn.ReLU(True)
            convs = [mpool, conv1, relu, conv2, relu]
            if self.batch_norm:
                b_norm = nn.BatchNorm2d(size)
                convs = [mpool, conv1, b_norm, relu, conv2, b_norm, relu]
            if i == 0:
                convs = convs[1:]
            block = nn.Sequential(*convs)
            blocks.append(block)
            old = size
            self.add_module(f'contract{i+1}', block)
        return blocks

    def expand(self):
        """Define expansion block in U-Net
        """
        blocks = []
        expand_filters = self.filter_sizes[self.n_block - 2::-1]
        old = self.filter_sizes[-1]
        for i, size in enumerate(expand_filters):
            up = nn.ConvTranspose2d(old, size, kernel_size=2, stride=2)
            self.add_module(f'up{i+1}', up)
            conv1 = nn.Conv2d(old, size, kernel_size=3)
            conv2 = nn.Conv2d(size, size, kernel_size=3)
            relu = nn.ReLU(True)
            convs = [conv1, relu, conv2, relu]
            if self.batch_norm:
                b_norm = nn.BatchNorm2d(size)
                convs = [conv1, b_norm, relu, conv2, b_norm, relu]
            convs = nn.Sequential(*convs)
            self.add_module(f'deconv{i+1}', convs)
            blocks.append({'up': up, 'conv': convs})

            old = size

        return blocks

# %% [markdown]
# ### Downloading Pretrained Model

# %%
if os.path.exists(pretrained_model_path) is False:
  print("Downloading pretrained model")
  os.makedirs(pretrained_model_path, exist_ok=True)
  # !wget https://www.dropbox.com/s/mbwbv4k1kyjpz5f/UNet50.pt?dl=0 -O checkpoints/UNet50.pt
else:
  print('Already Downloaded')
# Out:
# Already Downloaded

# %% [markdown]
# ### Downloading VNC Dataset

# %%
if os.path.exists(data_dir) is False:
  print("Downloading Dataset")
  os.makedirs(data_dir, exist_ok=True)
  # !wget https://github.com/hayashimasa/UNet-PyTorch/raw/main/data/test-volume.tif -O /content/drive/MyDrive/Colab_Notebooks/data/VNC/test-volume.tif
  # !wget https://github.com/hayashimasa/UNet-PyTorch/raw/main/data/train-labels.tif -O /content/drive/MyDrive/Colab_Notebooks/data/VNC/train-labels.tif
  # !wget https://github.com/hayashimasa/UNet-PyTorch/raw/main/data/train-volume.tif -O /content/drive/MyDrive/Colab_Notebooks/data/VNC/train-volume.tif
else:
  print('Dataset Already Downloaded')
# Out:
# Dataset Already Downloaded

# %% [markdown]
# ### visualizing Dataset

# %%
img_trn = tiff.imread(data_dir+f'/train-volume.tif')
msk_trn = tiff.imread(data_dir+f'/train-labels.tif')

index=1 
for img,msk in zip(img_trn, msk_trn):
    _img = resize(img, (128,128))
    _msk = resize(msk, (128,128)).round()
    fig,_ = plt.subplots(nrows=1, ncols=2)
    fig.axes[0].imshow(_img, cmap='gray')
    fig.axes[1].imshow(_msk, cmap='gray')
    plt.show()
    if(index==3):
      break
    index+=1

# %% [markdown]
# ### Helper Functions for Loading Data and Training

# %%
def get_train_loader(mean, std, out_size, batch_size, pct=.9):
    """Initialize Dataloader for training set

        mean (float): mean of pixel values
        std (float): standard deviation of pixel values
        out_size (int): dimension of segmentation map (out_size x out_size)
        batch_size (int): number of samples to load for each iteration
        pct (float): percentage of data to use for training (0 < pct <= 1)
    """
    image_mask_transform = DoubleCompose([
        DoubleToTensor(),
        DoubleElasticTransform(alpha=250, sigma=10),
        DoubleHorizontalFlip(),
        DoubleVerticalFlip()
    ])
    image_transform = transforms.Compose([
        transforms.ColorJitter(brightness=0.4),
        transforms.Normalize(mean, std),
        GaussianNoise(),
        transforms.Pad(30, padding_mode='reflect')
    ])
    mask_transform = transforms.CenterCrop(out_size)

    train_data = CellDataset(
        image_mask_transform=image_mask_transform,
        image_transform=image_transform,
        mask_transform=mask_transform,
        pct=pct
    )
    train_loader = DataLoader(
        train_data,
        batch_size=batch_size,
        shuffle=True
    )
    return train_loader


def get_test_loader(mean, std, out_size, batch_size):
    """Initialize Dataloader for validation set

        mean (float): mean of pixel values
        std (float): standard deviation of pixel values
        out_size (int): dimension of segmentation map (out_size x out_size)
        batch_size (int): number of samples to load for each iteration
    """
    image_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.Pad(30, padding_mode='reflect')
    ])
    mask_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.CenterCrop(388)
    ])

    test_data = CellDataset(
        image_transform=image_transform,
        mask_transform=mask_transform,
        data_type='validate'
    )

    test_loader = DataLoader(
        test_data,
        batch_size=batch_size,
        shuffle=False
    )
    return test_loader


def train(model, device, data_loader, optimizer, criterion, epoch):
    """train model for one epoch

    """
    model.train()
    loss = 0.
    for step, sample in enumerate(data_loader):
        # forward pass
        X = sample['image'].to(device)
        y = sample['mask'].to(device)
        w = sample['weight'].to(device)
        y = y.squeeze(1).long()  # remove channel dimension
        y_pred = model(X)

        # back propogation
        loss = criterion(y_pred, y, w)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # log
        log_interval = 1
        if step % log_interval == 0:
            print(
                'Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, (step+1) * len(X), len(data_loader.dataset),
                    100. * (step+1) / len(data_loader), loss.item()
                )
            )
        # break

    return loss.item()


def validate(model, device, data_loader, criterion, n_classes):
    """Evaluate model performance with validation data

    """
    model.eval()
    test_loss = 0
    n = len(data_loader.dataset)
    class_iou = [0.] * n_classes
    pixel_acc = 0.
    with torch.no_grad():
        for sample in data_loader:
            X = sample['image'].to(device)
            y = sample['mask'].to(device)
            w = sample['weight'].to(device)
            y = y.squeeze(1).long()  # remove channel dimension
            y_pred = model(X)
            test_loss += criterion(y_pred, y, w).item()  # sum up batch loss
            pred = torch.argmax(y_pred, dim=1)
            batch_size = X.shape[0]
            pred = pred.view(batch_size, -1)
            y = y.view(batch_size, -1)
            batch_iou = iou(pred, y, batch_size, n_classes)
            class_iou += batch_iou * (batch_size / n)
            pixel_acc += pix_acc(pred, y, batch_size) * (batch_size / n)

    data_size = len(data_loader.dataset)
    test_loss /= data_size
    avg_iou = np.mean(class_iou)

    print(
        '\nValidation set: Average loss: {:.4f}, '.format(test_loss)
        + 'Average IOU score: {:.2f}, '.format(avg_iou)
        + 'Average pixel accuracy: {:.2f}\n'.format(pixel_acc)
    )
    return test_loss, avg_iou, pixel_acc


def initialize_model():
    """Initialize model checkpoint dictionary for storing training progress

    Args:
        args (object):
            epoch (int): total number of epochs to train model
            n_classes (int): number of segmentation classes
    """
    model_dict = {
        'total_epoch': epochs,
        'n_classes': 2,
        'model_state_dict': None,
        'optimizer_state_dict': None,
        'train_loss': list(),
        'test_loss': list(),
        'metrics': {
            'IOU': list(),
            'pix_acc': list(),
            'best': {
                'IOU': 0.,
                'pixel_acc': 0.,
                'epoch': 0
            }
        }
    }
    return model_dict

# %% [markdown]
# ### Training

# %%
def get_model(device):
    """Intialize or load model checkpoint and intialize model and optimizer

    """
    
    # Load model checkpoint
    model_dict = torch.load(pretrained_model_path+f'/UNet50.pt')
    # else:
    #     model_dict = initialize_model(args)
    n_classes = model_dict['n_classes']
    model = UNet(n_classes).cuda() if device == 'cuda' else UNet(n_classes)
    optimizer = optim.Adam(model.parameters(),lr)
    
    model.load_state_dict(model_dict['model_state_dict'])
    optimizer.load_state_dict(model_dict['optimizer_state_dict'])
    return model, optimizer, model_dict



    # args = parse_args()
    # if args.tensorboard:
writer = SummaryWriter()
# initialize model
device = (
    'cuda' if torch.cuda.is_available() else 'cpu'
)
model, optimizer, model_dict = get_model(device)
# initialize dataloader
mean = 0.495
std = 0.173
out_size = 388  # output dimension of segmentation map
train_loader = get_train_loader(mean, std, out_size, batch_size)
test_loader = get_test_loader(mean, std, out_size, test_batch_size)
# define loss function
criterion = Weighted_Cross_Entropy_Loss()
# train and evaluate model
start_epoch = 1  

n_epoch = start_epoch + epochs - 1
model_path = pretrained_model_path
if not os.path.isdir(model_path):
    os.mkdir(model_path)
model_name =f'checkpoints/UNet{epochs}.pt'
for epoch in range(start_epoch, n_epoch + 1):
    train_loss = train(
        model, device, train_loader, optimizer, criterion, epoch
    )
    test_loss, test_iou, test_pix_acc = validate(
        model, device, test_loader, criterion, 2
    )
    # update tensorboard
    # if args.tensorboard:
    writer.add_scalar('Loss/train', train_loss, epoch)
    writer.add_scalar('Loss/test', test_loss, epoch)
    writer.add_scalar('IOU/test', test_iou, epoch)
    writer.add_scalar('Pixel_Accuracy/test', test_pix_acc, epoch)
    # record training progress
    model_dict['train_loss'].append(train_loss)
    model_dict['test_loss'].append(test_loss)
    model_dict['metrics']['IOU'].append(test_iou)
    model_dict['metrics']['pix_acc'].append(test_pix_acc)
    if epoch == 1 or test_iou > model_dict['metrics']['best']['IOU']:
        model_dict['model_state_dict'] = model.state_dict()
        model_dict['optimizer_state_dict'] = optimizer.state_dict()
        model_dict['metrics']['best']['IOU'] = test_iou
        model_dict['metrics']['best']['pix_acc'] = test_pix_acc
        model_dict['metrics']['best']['epoch'] = epoch
    # if args.save:
    torch.save(model_dict, model_name)
# if args.tensorboard:
writer.close()
print('Best IOU:', model_dict['metrics']['best']['IOU'])
print('Pixel accuracy:', model_dict['metrics']['best']['pix_acc'])
# Out:
# Train Epoch: 1 [3/27 (11%)]	Loss: 0.115986
# Train Epoch: 1 [6/27 (22%)]	Loss: 0.101055
# Train Epoch: 1 [9/27 (33%)]	Loss: 0.111096
# Train Epoch: 1 [12/27 (44%)]	Loss: 0.137838
# Train Epoch: 1 [15/27 (56%)]	Loss: 0.165764
# Train Epoch: 1 [18/27 (67%)]	Loss: 0.088499
# Train Epoch: 1 [21/27 (78%)]	Loss: 0.134409
# Train Epoch: 1 [24/27 (89%)]	Loss: 0.139308
# Train Epoch: 1 [27/27 (100%)]	Loss: 0.108339
#
# Validation set: Average loss: 0.1157, Average IOU score: 0.72, Average pixel accuracy: 0.89
#
# Train Epoch: 2 [3/27 (11%)]	Loss: 0.115998
# Train Epoch: 2 [6/27 (22%)]	Loss: 0.130009
# Train Epoch: 2 [9/27 (33%)]	Loss: 0.131259
# Train Epoch: 2 [12/27 (44%)]	Loss: 0.153541
# Train Epoch: 2 [15/27 (56%)]	Loss: 0.105936
# Train Epoch: 2 [18/27 (67%)]	Loss: 0.128207
# Train Epoch: 2 [21/27 (78%)]	Loss: 0.113266
# Train Epoch: 2 [24/27 (89%)]	Loss: 0.107728
# Train Epoch: 2 [27/27 (100%)]	Loss: 0.128152
#
# Validation set: Average loss: 0.1119, Average IOU score: 0.71, Average pixel accuracy: 0.89
#
# Train Epoch: 3 [3/27 (11%)]	Loss: 0.105055
# Train Epoch: 3 [6/27 (22%)]	Loss: 0.129714
# Train Epoch: 3 [9/27 (33%)]	Loss: 0.104458
# Train Epoch: 3 [12/27 (44%)]	Loss: 0.109481
# Train Epoch: 3 [15/27 (56%)]	Loss: 0.153313
# Train Epoch: 3 [18/27 (67%)]	Loss: 0.082695
# Train Epoch: 3 [21/27 (78%)]	Loss: 0.143925
# Train Epoch: 3 [24/27 (89%)]	Loss: 0.156112
# Train Epoch: 3 [27/27 (100%)]	Loss: 0.113835
#
# Validation set: Average loss: 0.1141, Average IOU score: 0.72, Average pixel accuracy: 0.89
#
# Train Epoch: 4 [3/27 (11%)]	Loss: 0.128707
# Train Epoch: 4 [6/27 (22%)]	Loss: 0.169646
# Train Epoch: 4 [9/27 (33%)]	Loss: 0.111991
# Train Epoch: 4 [12/27 (44%)]	Loss: 0.102294
# Train Epoch: 4 [15/27 (56%)]	Loss: 0.115276
# Train Epoch: 4 [18/27 (67%)]	Loss: 0.113707
# Train Epoch: 4 [21/27 (78%)]	Loss: 0.138039
# Train Epoch: 4 [24/27 (89%)]	Loss: 0.118882
# Train Epoch: 4 [27/27 (100%)]	Loss: 0.112331
#
# Validation set: Average loss: 0.1076, Average IOU score: 0.73, Average pixel accuracy: 0.90
#
# Train Epoch: 5 [3/27 (11%)]	Loss: 0.148710
# Train Epoch: 5 [6/27 (22%)]	Loss: 0.087228
# Train Epoch: 5 [9/27 (33%)]	Loss: 0.122983
# Train Epoch: 5 [12/27 (44%)]	Loss: 0.130609
# Train Epoch: 5 [15/27 (56%)]	Loss: 0.086597
# Train Epoch: 5 [18/27 (67%)]	Loss: 0.137170
# Train Epoch: 5 [21/27 (78%)]	Loss: 0.133641
# Train Epoch: 5 [24/27 (89%)]	Loss: 0.126352
# Train Epoch: 5 [27/27 (100%)]	Loss: 0.120557
#
# Validation set: Average loss: 0.1273, Average IOU score: 0.72, Average pixel accuracy: 0.89
#
# Train Epoch: 6 [3/27 (11%)]	Loss: 0.084596
# Train Epoch: 6 [6/27 (22%)]	Loss: 0.107626
# Train Epoch: 6 [9/27 (33%)]	Loss: 0.103941
# Train Epoch: 6 [12/27 (44%)]	Loss: 0.102871
# Train Epoch: 6 [15/27 (56%)]	Loss: 0.087154
# Train Epoch: 6 [18/27 (67%)]	Loss: 0.127303
# Train Epoch: 6 [21/27 (78%)]	Loss: 0.124375
# Train Epoch: 6 [24/27 (89%)]	Loss: 0.135611
# Train Epoch: 6 [27/27 (100%)]	Loss: 0.099685
#
# Validation set: Average loss: 0.1192, Average IOU score: 0.71, Average pixel accuracy: 0.89
#
# Train Epoch: 7 [3/27 (11%)]	Loss: 0.137166
# Train Epoch: 7 [6/27 (22%)]	Loss: 0.114003
# Train Epoch: 7 [9/27 (33%)]	Loss: 0.108755
# Train Epoch: 7 [12/27 (44%)]	Loss: 0.100364
# Train Epoch: 7 [15/27 (56%)]	Loss: 0.083186
# Train Epoch: 7 [18/27 (67%)]	Loss: 0.098903
# Train Epoch: 7 [21/27 (78%)]	Loss: 0.121557
# Train Epoch: 7 [24/27 (89%)]	Loss: 0.107596
# Train Epoch: 7 [27/27 (100%)]	Loss: 0.147828
#
# Validation set: Average loss: 0.1217, Average IOU score: 0.71, Average pixel accuracy: 0.89
#
# Train Epoch: 8 [3/27 (11%)]	Loss: 0.108057
# Train Epoch: 8 [6/27 (22%)]	Loss: 0.116023
# Train Epoch: 8 [9/27 (33%)]	Loss: 0.124984
# Train Epoch: 8 [12/27 (44%)]	Loss: 0.080496
# Train Epoch: 8 [15/27 (56%)]	Loss: 0.105551
# Train Epoch: 8 [18/27 (67%)]	Loss: 0.105364
# Train Epoch: 8 [21/27 (78%)]	Loss: 0.123137
# Train Epoch: 8 [24/27 (89%)]	Loss: 0.083370
# Train Epoch: 8 [27/27 (100%)]	Loss: 0.119112
#
# Validation set: Average loss: 0.1300, Average IOU score: 0.69, Average pixel accuracy: 0.87
#
# Train Epoch: 9 [3/27 (11%)]	Loss: 0.120183
# Train Epoch: 9 [6/27 (22%)]	Loss: 0.127648
# Train Epoch: 9 [9/27 (33%)]	Loss: 0.160723
# Train Epoch: 9 [12/27 (44%)]	Loss: 0.142146
# Train Epoch: 9 [15/27 (56%)]	Loss: 0.129281
# Train Epoch: 9 [18/27 (67%)]	Loss: 0.080182
# Train Epoch: 9 [21/27 (78%)]	Loss: 0.082360
# Train Epoch: 9 [24/27 (89%)]	Loss: 0.131086
# Train Epoch: 9 [27/27 (100%)]	Loss: 0.123423
#
# Validation set: Average loss: 0.1033, Average IOU score: 0.71, Average pixel accuracy: 0.90
#
# Train Epoch: 10 [3/27 (11%)]	Loss: 0.129225
# Train Epoch: 10 [6/27 (22%)]	Loss: 0.123166
# Train Epoch: 10 [9/27 (33%)]	Loss: 0.084523
# Train Epoch: 10 [12/27 (44%)]	Loss: 0.105743
# Train Epoch: 10 [15/27 (56%)]	Loss: 0.121548
# Train Epoch: 10 [18/27 (67%)]	Loss: 0.104963
# Train Epoch: 10 [21/27 (78%)]	Loss: 0.122302
# Train Epoch: 10 [24/27 (89%)]	Loss: 0.099964
# Train Epoch: 10 [27/27 (100%)]	Loss: 0.123826
#
# Validation set: Average loss: 0.0979, Average IOU score: 0.63, Average pixel accuracy: 0.87
#
# Train Epoch: 11 [3/27 (11%)]	Loss: 0.123706
# Train Epoch: 11 [6/27 (22%)]	Loss: 0.126464
# Train Epoch: 11 [9/27 (33%)]	Loss: 0.115800
# Train Epoch: 11 [12/27 (44%)]	Loss: 0.142346
# Train Epoch: 11 [15/27 (56%)]	Loss: 0.154623
# Train Epoch: 11 [18/27 (67%)]	Loss: 0.152825
# Train Epoch: 11 [21/27 (78%)]	Loss: 0.102102
# Train Epoch: 11 [24/27 (89%)]	Loss: 0.127017
# Train Epoch: 11 [27/27 (100%)]	Loss: 0.114865
#
# Validation set: Average loss: 0.1236, Average IOU score: 0.73, Average pixel accuracy: 0.89
#
# Train Epoch: 12 [3/27 (11%)]	Loss: 0.105960
# Train Epoch: 12 [6/27 (22%)]	Loss: 0.082065
# Train Epoch: 12 [9/27 (33%)]	Loss: 0.129714
# Train Epoch: 12 [12/27 (44%)]	Loss: 0.115719
# Train Epoch: 12 [15/27 (56%)]	Loss: 0.111346
# Train Epoch: 12 [18/27 (67%)]	Loss: 0.097063
# Train Epoch: 12 [21/27 (78%)]	Loss: 0.102953
# Train Epoch: 12 [24/27 (89%)]	Loss: 0.128915
# Train Epoch: 12 [27/27 (100%)]	Loss: 0.084441
#
# Validation set: Average loss: 0.1307, Average IOU score: 0.69, Average pixel accuracy: 0.86
#
# Train Epoch: 13 [3/27 (11%)]	Loss: 0.122333
# Train Epoch: 13 [6/27 (22%)]	Loss: 0.071438
# Train Epoch: 13 [9/27 (33%)]	Loss: 0.099078
# Train Epoch: 13 [12/27 (44%)]	Loss: 0.122091
# Train Epoch: 13 [15/27 (56%)]	Loss: 0.128256
# Train Epoch: 13 [18/27 (67%)]	Loss: 0.069448
# Train Epoch: 13 [21/27 (78%)]	Loss: 0.148703
# Train Epoch: 13 [24/27 (89%)]	Loss: 0.129397
# Train Epoch: 13 [27/27 (100%)]	Loss: 0.098925
#
# Validation set: Average loss: 0.0964, Average IOU score: 0.65, Average pixel accuracy: 0.88
#
# Train Epoch: 14 [3/27 (11%)]	Loss: 0.117261
# Train Epoch: 14 [6/27 (22%)]	Loss: 0.096724
# Train Epoch: 14 [9/27 (33%)]	Loss: 0.074598
# Train Epoch: 14 [12/27 (44%)]	Loss: 0.104454
# Train Epoch: 14 [15/27 (56%)]	Loss: 0.118860
# Train Epoch: 14 [18/27 (67%)]	Loss: 0.106136
# Train Epoch: 14 [21/27 (78%)]	Loss: 0.093433
# Train Epoch: 14 [24/27 (89%)]	Loss: 0.131866
# Train Epoch: 14 [27/27 (100%)]	Loss: 0.073496
#
# Validation set: Average loss: 0.1020, Average IOU score: 0.69, Average pixel accuracy: 0.88
#
# Train Epoch: 15 [3/27 (11%)]	Loss: 0.100826
# Train Epoch: 15 [6/27 (22%)]	Loss: 0.129343
# Train Epoch: 15 [9/27 (33%)]	Loss: 0.147100
# Train Epoch: 15 [12/27 (44%)]	Loss: 0.113744
# Train Epoch: 15 [15/27 (56%)]	Loss: 0.119837
# Train Epoch: 15 [18/27 (67%)]	Loss: 0.109796
# Train Epoch: 15 [21/27 (78%)]	Loss: 0.073668
# Train Epoch: 15 [24/27 (89%)]	Loss: 0.153439
# Train Epoch: 15 [27/27 (100%)]	Loss: 0.074193
#
# Validation set: Average loss: 0.1256, Average IOU score: 0.71, Average pixel accuracy: 0.88
#
# Train Epoch: 16 [3/27 (11%)]	Loss: 0.145425
# Train Epoch: 16 [6/27 (22%)]	Loss: 0.118987
# Train Epoch: 16 [9/27 (33%)]	Loss: 0.115569
# Train Epoch: 16 [12/27 (44%)]	Loss: 0.095101
# Train Epoch: 16 [15/27 (56%)]	Loss: 0.112964
# Train Epoch: 16 [18/27 (67%)]	Loss: 0.094241
# Train Epoch: 16 [21/27 (78%)]	Loss: 0.115868
# Train Epoch: 16 [24/27 (89%)]	Loss: 0.153835
# Train Epoch: 16 [27/27 (100%)]	Loss: 0.083797
#
# Validation set: Average loss: 0.1209, Average IOU score: 0.70, Average pixel accuracy: 0.87
#
# Train Epoch: 17 [3/27 (11%)]	Loss: 0.073295
# Train Epoch: 17 [6/27 (22%)]	Loss: 0.110576
# Train Epoch: 17 [9/27 (33%)]	Loss: 0.093057
# Train Epoch: 17 [12/27 (44%)]	Loss: 0.092989
# Train Epoch: 17 [15/27 (56%)]	Loss: 0.092948
# Train Epoch: 17 [18/27 (67%)]	Loss: 0.075426
# Train Epoch: 17 [21/27 (78%)]	Loss: 0.108660
# Train Epoch: 17 [24/27 (89%)]	Loss: 0.094163
# Train Epoch: 17 [27/27 (100%)]	Loss: 0.129022
#
# Validation set: Average loss: 0.0987, Average IOU score: 0.69, Average pixel accuracy: 0.89
#
# Train Epoch: 18 [3/27 (11%)]	Loss: 0.120752
# Train Epoch: 18 [6/27 (22%)]	Loss: 0.094307
# Train Epoch: 18 [9/27 (33%)]	Loss: 0.129478
# Train Epoch: 18 [12/27 (44%)]	Loss: 0.120276
# Train Epoch: 18 [15/27 (56%)]	Loss: 0.122573
# Train Epoch: 18 [18/27 (67%)]	Loss: 0.150102
# Train Epoch: 18 [21/27 (78%)]	Loss: 0.125446
# Train Epoch: 18 [24/27 (89%)]	Loss: 0.094722
# Train Epoch: 18 [27/27 (100%)]	Loss: 0.117646
#
# Validation set: Average loss: 0.0909, Average IOU score: 0.70, Average pixel accuracy: 0.89
#
# Train Epoch: 19 [3/27 (11%)]	Loss: 0.092278
# Train Epoch: 19 [6/27 (22%)]	Loss: 0.121591
# Train Epoch: 19 [9/27 (33%)]	Loss: 0.109953
# Train Epoch: 19 [12/27 (44%)]	Loss: 0.099196
# Train Epoch: 19 [15/27 (56%)]	Loss: 0.116986
# Train Epoch: 19 [18/27 (67%)]	Loss: 0.105830
# Train Epoch: 19 [21/27 (78%)]	Loss: 0.080344
# Train Epoch: 19 [24/27 (89%)]	Loss: 0.096906
# Train Epoch: 19 [27/27 (100%)]	Loss: 0.114892
#
# Validation set: Average loss: 0.1069, Average IOU score: 0.66, Average pixel accuracy: 0.88
#
# Train Epoch: 20 [3/27 (11%)]	Loss: 0.093673
# Train Epoch: 20 [6/27 (22%)]	Loss: 0.148328
# Train Epoch: 20 [9/27 (33%)]	Loss: 0.091110
# Train Epoch: 20 [12/27 (44%)]	Loss: 0.127186
# Train Epoch: 20 [15/27 (56%)]	Loss: 0.117775
# Train Epoch: 20 [18/27 (67%)]	Loss: 0.089898
# Train Epoch: 20 [21/27 (78%)]	Loss: 0.091742
# Train Epoch: 20 [24/27 (89%)]	Loss: 0.091759
# Train Epoch: 20 [27/27 (100%)]	Loss: 0.085820
#
# Validation set: Average loss: 0.0939, Average IOU score: 0.60, Average pixel accuracy: 0.86
#
# Train Epoch: 21 [3/27 (11%)]	Loss: 0.090780
# Train Epoch: 21 [6/27 (22%)]	Loss: 0.120487
# Train Epoch: 21 [9/27 (33%)]	Loss: 0.120497
# Train Epoch: 21 [12/27 (44%)]	Loss: 0.090242
# Train Epoch: 21 [15/27 (56%)]	Loss: 0.129035
# Train Epoch: 21 [18/27 (67%)]	Loss: 0.086770
# Train Epoch: 21 [21/27 (78%)]	Loss: 0.090374
# Train Epoch: 21 [24/27 (89%)]	Loss: 0.134434
# Train Epoch: 21 [27/27 (100%)]	Loss: 0.072647
#
# Validation set: Average loss: 0.0869, Average IOU score: 0.65, Average pixel accuracy: 0.88
#
# Train Epoch: 22 [3/27 (11%)]	Loss: 0.063326
# Train Epoch: 22 [6/27 (22%)]	Loss: 0.127686
# Train Epoch: 22 [9/27 (33%)]	Loss: 0.082960
# Train Epoch: 22 [12/27 (44%)]	Loss: 0.090383
# Train Epoch: 22 [15/27 (56%)]	Loss: 0.118050
# Train Epoch: 22 [18/27 (67%)]	Loss: 0.110723
# Train Epoch: 22 [21/27 (78%)]	Loss: 0.114723
# Train Epoch: 22 [24/27 (89%)]	Loss: 0.087905
# Train Epoch: 22 [27/27 (100%)]	Loss: 0.090518
#
# Validation set: Average loss: 0.0972, Average IOU score: 0.69, Average pixel accuracy: 0.89
#
# Train Epoch: 23 [3/27 (11%)]	Loss: 0.061833
# Train Epoch: 23 [6/27 (22%)]	Loss: 0.096082
# Train Epoch: 23 [9/27 (33%)]	Loss: 0.163160
# Train Epoch: 23 [12/27 (44%)]	Loss: 0.088407
# Train Epoch: 23 [15/27 (56%)]	Loss: 0.129270
# Train Epoch: 23 [18/27 (67%)]	Loss: 0.084827
# Train Epoch: 23 [21/27 (78%)]	Loss: 0.089734
# Train Epoch: 23 [24/27 (89%)]	Loss: 0.060414
# Train Epoch: 23 [27/27 (100%)]	Loss: 0.107288
#
# Validation set: Average loss: 0.0857, Average IOU score: 0.59, Average pixel accuracy: 0.86
#
# Train Epoch: 24 [3/27 (11%)]	Loss: 0.067019
# Train Epoch: 24 [6/27 (22%)]	Loss: 0.062600
# Train Epoch: 24 [9/27 (33%)]	Loss: 0.116160
# Train Epoch: 24 [12/27 (44%)]	Loss: 0.084019
# Train Epoch: 24 [15/27 (56%)]	Loss: 0.111532
# Train Epoch: 24 [18/27 (67%)]	Loss: 0.098686
# Train Epoch: 24 [21/27 (78%)]	Loss: 0.058176
# Train Epoch: 24 [24/27 (89%)]	Loss: 0.086864
# Train Epoch: 24 [27/27 (100%)]	Loss: 0.083938
#
# Validation set: Average loss: 0.0999, Average IOU score: 0.69, Average pixel accuracy: 0.89
#
# Train Epoch: 25 [3/27 (11%)]	Loss: 0.087909
# Train Epoch: 25 [6/27 (22%)]	Loss: 0.082863
# Train Epoch: 25 [9/27 (33%)]	Loss: 0.115397
# Train Epoch: 25 [12/27 (44%)]	Loss: 0.139744
# Train Epoch: 25 [15/27 (56%)]	Loss: 0.085762
# Train Epoch: 25 [18/27 (67%)]	Loss: 0.062307
# Train Epoch: 25 [21/27 (78%)]	Loss: 0.121296
# Train Epoch: 25 [24/27 (89%)]	Loss: 0.083467
# Train Epoch: 25 [27/27 (100%)]	Loss: 0.144038
#
# Validation set: Average loss: 0.0891, Average IOU score: 0.66, Average pixel accuracy: 0.88
#
# Train Epoch: 26 [3/27 (11%)]	Loss: 0.092703
# Train Epoch: 26 [6/27 (22%)]	Loss: 0.116561
# Train Epoch: 26 [9/27 (33%)]	Loss: 0.108923
# Train Epoch: 26 [12/27 (44%)]	Loss: 0.120789
# Train Epoch: 26 [15/27 (56%)]	Loss: 0.088504
# Train Epoch: 26 [18/27 (67%)]	Loss: 0.092321
# Train Epoch: 26 [21/27 (78%)]	Loss: 0.141012
# Train Epoch: 26 [24/27 (89%)]	Loss: 0.085944
# Train Epoch: 26 [27/27 (100%)]	Loss: 0.119462
#
# Validation set: Average loss: 0.1032, Average IOU score: 0.73, Average pixel accuracy: 0.89
#
# Train Epoch: 27 [3/27 (11%)]	Loss: 0.065936
# Train Epoch: 27 [6/27 (22%)]	Loss: 0.091157
# Train Epoch: 27 [9/27 (33%)]	Loss: 0.106483
# Train Epoch: 27 [12/27 (44%)]	Loss: 0.096379
# Train Epoch: 27 [15/27 (56%)]	Loss: 0.115008
# Train Epoch: 27 [18/27 (67%)]	Loss: 0.109849
# Train Epoch: 27 [21/27 (78%)]	Loss: 0.136904
# Train Epoch: 27 [24/27 (89%)]	Loss: 0.106572
# Train Epoch: 27 [27/27 (100%)]	Loss: 0.142189
#
# Validation set: Average loss: 0.1138, Average IOU score: 0.70, Average pixel accuracy: 0.88
#
# Train Epoch: 28 [3/27 (11%)]	Loss: 0.112893
# Train Epoch: 28 [6/27 (22%)]	Loss: 0.105895
# Train Epoch: 28 [9/27 (33%)]	Loss: 0.105308
# Train Epoch: 28 [12/27 (44%)]	Loss: 0.115711
# Train Epoch: 28 [15/27 (56%)]	Loss: 0.117444
# Train Epoch: 28 [18/27 (67%)]	Loss: 0.114459
# Train Epoch: 28 [21/27 (78%)]	Loss: 0.085426
# Train Epoch: 28 [24/27 (89%)]	Loss: 0.092412
# Train Epoch: 28 [27/27 (100%)]	Loss: 0.090773
#
# Validation set: Average loss: 0.1278, Average IOU score: 0.68, Average pixel accuracy: 0.86
#
# Train Epoch: 29 [3/27 (11%)]	Loss: 0.090201
# Train Epoch: 29 [6/27 (22%)]	Loss: 0.088073
# Train Epoch: 29 [9/27 (33%)]	Loss: 0.115350
# Train Epoch: 29 [12/27 (44%)]	Loss: 0.130692
# Train Epoch: 29 [15/27 (56%)]	Loss: 0.082525
# Train Epoch: 29 [18/27 (67%)]	Loss: 0.108879
# Train Epoch: 29 [21/27 (78%)]	Loss: 0.124617
# Train Epoch: 29 [24/27 (89%)]	Loss: 0.087537
# Train Epoch: 29 [27/27 (100%)]	Loss: 0.056249
#
# Validation set: Average loss: 0.1155, Average IOU score: 0.72, Average pixel accuracy: 0.89
#
# Train Epoch: 30 [3/27 (11%)]	Loss: 0.112219
# Train Epoch: 30 [6/27 (22%)]	Loss: 0.110164
# Train Epoch: 30 [9/27 (33%)]	Loss: 0.082672
# Train Epoch: 30 [12/27 (44%)]	Loss: 0.141074
# Train Epoch: 30 [15/27 (56%)]	Loss: 0.111314
# Train Epoch: 30 [18/27 (67%)]	Loss: 0.101483
# Train Epoch: 30 [21/27 (78%)]	Loss: 0.095405
# Train Epoch: 30 [24/27 (89%)]	Loss: 0.120676
# Train Epoch: 30 [27/27 (100%)]	Loss: 0.081897
#
# Validation set: Average loss: 0.1094, Average IOU score: 0.72, Average pixel accuracy: 0.89
#
# Train Epoch: 31 [3/27 (11%)]	Loss: 0.107300
# Train Epoch: 31 [6/27 (22%)]	Loss: 0.092321
# Train Epoch: 31 [9/27 (33%)]	Loss: 0.062244
# Train Epoch: 31 [12/27 (44%)]	Loss: 0.084987
# Train Epoch: 31 [15/27 (56%)]	Loss: 0.080659
# Train Epoch: 31 [18/27 (67%)]	Loss: 0.113725
# Train Epoch: 31 [21/27 (78%)]	Loss: 0.112638
# Train Epoch: 31 [24/27 (89%)]	Loss: 0.081227
# Train Epoch: 31 [27/27 (100%)]	Loss: 0.083095
#
# Validation set: Average loss: 0.1060, Average IOU score: 0.70, Average pixel accuracy: 0.89
#
# Train Epoch: 32 [3/27 (11%)]	Loss: 0.103544
# Train Epoch: 32 [6/27 (22%)]	Loss: 0.110280
# Train Epoch: 32 [9/27 (33%)]	Loss: 0.055436
# Train Epoch: 32 [12/27 (44%)]	Loss: 0.077817
# Train Epoch: 32 [15/27 (56%)]	Loss: 0.085887
# Train Epoch: 32 [18/27 (67%)]	Loss: 0.143481
# Train Epoch: 32 [21/27 (78%)]	Loss: 0.074693
# Train Epoch: 32 [24/27 (89%)]	Loss: 0.083988
# Train Epoch: 32 [27/27 (100%)]	Loss: 0.133019
#
# Validation set: Average loss: 0.1448, Average IOU score: 0.67, Average pixel accuracy: 0.85
#
# Train Epoch: 33 [3/27 (11%)]	Loss: 0.082764
# Train Epoch: 33 [6/27 (22%)]	Loss: 0.063005
# Train Epoch: 33 [9/27 (33%)]	Loss: 0.086074
# Train Epoch: 33 [12/27 (44%)]	Loss: 0.121434
# Train Epoch: 33 [15/27 (56%)]	Loss: 0.077378
# Train Epoch: 33 [18/27 (67%)]	Loss: 0.081404
# Train Epoch: 33 [21/27 (78%)]	Loss: 0.117697
# Train Epoch: 33 [24/27 (89%)]	Loss: 0.078656
# Train Epoch: 33 [27/27 (100%)]	Loss: 0.078772
#
# Validation set: Average loss: 0.1213, Average IOU score: 0.69, Average pixel accuracy: 0.87
#
# Train Epoch: 34 [3/27 (11%)]	Loss: 0.085836
# Train Epoch: 34 [6/27 (22%)]	Loss: 0.086977
# Train Epoch: 34 [9/27 (33%)]	Loss: 0.076913
# Train Epoch: 34 [12/27 (44%)]	Loss: 0.077718
# Train Epoch: 34 [15/27 (56%)]	Loss: 0.081215
# Train Epoch: 34 [18/27 (67%)]	Loss: 0.119876
# Train Epoch: 34 [21/27 (78%)]	Loss: 0.109957
# Train Epoch: 34 [24/27 (89%)]	Loss: 0.078028
# Train Epoch: 34 [27/27 (100%)]	Loss: 0.104309
#
# Validation set: Average loss: 0.1490, Average IOU score: 0.65, Average pixel accuracy: 0.83
#
# Train Epoch: 35 [3/27 (11%)]	Loss: 0.130160
# Train Epoch: 35 [6/27 (22%)]	Loss: 0.082750
# Train Epoch: 35 [9/27 (33%)]	Loss: 0.079872
# Train Epoch: 35 [12/27 (44%)]	Loss: 0.108224
# Train Epoch: 35 [15/27 (56%)]	Loss: 0.102707
# Train Epoch: 35 [18/27 (67%)]	Loss: 0.107379
# Train Epoch: 35 [21/27 (78%)]	Loss: 0.115851
# Train Epoch: 35 [24/27 (89%)]	Loss: 0.126174
# Train Epoch: 35 [27/27 (100%)]	Loss: 0.109181
#
# Validation set: Average loss: 0.1440, Average IOU score: 0.65, Average pixel accuracy: 0.83
#
# Train Epoch: 36 [3/27 (11%)]	Loss: 0.123062
# Train Epoch: 36 [6/27 (22%)]	Loss: 0.068833
# Train Epoch: 36 [9/27 (33%)]	Loss: 0.069862
# Train Epoch: 36 [12/27 (44%)]	Loss: 0.118921
# Train Epoch: 36 [15/27 (56%)]	Loss: 0.111777
# Train Epoch: 36 [18/27 (67%)]	Loss: 0.080210
# Train Epoch: 36 [21/27 (78%)]	Loss: 0.104170
# Train Epoch: 36 [24/27 (89%)]	Loss: 0.101607
# Train Epoch: 36 [27/27 (100%)]	Loss: 0.109280
#
# Validation set: Average loss: 0.1318, Average IOU score: 0.69, Average pixel accuracy: 0.86
#
# Train Epoch: 37 [3/27 (11%)]	Loss: 0.076414
# Train Epoch: 37 [6/27 (22%)]	Loss: 0.110036
# Train Epoch: 37 [9/27 (33%)]	Loss: 0.077744
# Train Epoch: 37 [12/27 (44%)]	Loss: 0.120760
# Train Epoch: 37 [15/27 (56%)]	Loss: 0.103208
# Train Epoch: 37 [18/27 (67%)]	Loss: 0.108001
# Train Epoch: 37 [21/27 (78%)]	Loss: 0.104649
# Train Epoch: 37 [24/27 (89%)]	Loss: 0.128253
# Train Epoch: 37 [27/27 (100%)]	Loss: 0.060537
#
# Validation set: Average loss: 0.1110, Average IOU score: 0.70, Average pixel accuracy: 0.88
#
# Train Epoch: 38 [3/27 (11%)]	Loss: 0.081304
# Train Epoch: 38 [6/27 (22%)]	Loss: 0.062302
# Train Epoch: 38 [9/27 (33%)]	Loss: 0.076337
# Train Epoch: 38 [12/27 (44%)]	Loss: 0.125695
# Train Epoch: 38 [15/27 (56%)]	Loss: 0.059151
# Train Epoch: 38 [18/27 (67%)]	Loss: 0.106316
# Train Epoch: 38 [21/27 (78%)]	Loss: 0.100067
# Train Epoch: 38 [24/27 (89%)]	Loss: 0.102330
# Train Epoch: 38 [27/27 (100%)]	Loss: 0.099614
#
# Validation set: Average loss: 0.0964, Average IOU score: 0.71, Average pixel accuracy: 0.89
#
# Train Epoch: 39 [3/27 (11%)]	Loss: 0.106418
# Train Epoch: 39 [6/27 (22%)]	Loss: 0.106858
# Train Epoch: 39 [9/27 (33%)]	Loss: 0.108737
# Train Epoch: 39 [12/27 (44%)]	Loss: 0.058847
# Train Epoch: 39 [15/27 (56%)]	Loss: 0.138863
# Train Epoch: 39 [18/27 (67%)]	Loss: 0.112874
# Train Epoch: 39 [21/27 (78%)]	Loss: 0.087173
# Train Epoch: 39 [24/27 (89%)]	Loss: 0.134288
# Train Epoch: 39 [27/27 (100%)]	Loss: 0.102454
#
# Validation set: Average loss: 0.1054, Average IOU score: 0.73, Average pixel accuracy: 0.90
#
# Train Epoch: 40 [3/27 (11%)]	Loss: 0.079544
# Train Epoch: 40 [6/27 (22%)]	Loss: 0.063141
# Train Epoch: 40 [9/27 (33%)]	Loss: 0.055965
# Train Epoch: 40 [12/27 (44%)]	Loss: 0.089925
# Train Epoch: 40 [15/27 (56%)]	Loss: 0.074620
# Train Epoch: 40 [18/27 (67%)]	Loss: 0.077164
# Train Epoch: 40 [21/27 (78%)]	Loss: 0.075004
# Train Epoch: 40 [24/27 (89%)]	Loss: 0.079322
# Train Epoch: 40 [27/27 (100%)]	Loss: 0.083223
#
# Validation set: Average loss: 0.0990, Average IOU score: 0.66, Average pixel accuracy: 0.88
#
# Train Epoch: 41 [3/27 (11%)]	Loss: 0.145805
# Train Epoch: 41 [6/27 (22%)]	Loss: 0.110925
# Train Epoch: 41 [9/27 (33%)]	Loss: 0.073943
# Train Epoch: 41 [12/27 (44%)]	Loss: 0.106318
# Train Epoch: 41 [15/27 (56%)]	Loss: 0.080475
# Train Epoch: 41 [18/27 (67%)]	Loss: 0.071603
# Train Epoch: 41 [21/27 (78%)]	Loss: 0.139277
# Train Epoch: 41 [24/27 (89%)]	Loss: 0.108671
# Train Epoch: 41 [27/27 (100%)]	Loss: 0.081715
#
# Validation set: Average loss: 0.1008, Average IOU score: 0.74, Average pixel accuracy: 0.90
#
# Train Epoch: 42 [3/27 (11%)]	Loss: 0.076604
# Train Epoch: 42 [6/27 (22%)]	Loss: 0.103348
# Train Epoch: 42 [9/27 (33%)]	Loss: 0.081446
# Train Epoch: 42 [12/27 (44%)]	Loss: 0.080495
# Train Epoch: 42 [15/27 (56%)]	Loss: 0.101817
# Train Epoch: 42 [18/27 (67%)]	Loss: 0.116584
# Train Epoch: 42 [21/27 (78%)]	Loss: 0.143843
# Train Epoch: 42 [24/27 (89%)]	Loss: 0.112043
# Train Epoch: 42 [27/27 (100%)]	Loss: 0.126533
#
# Validation set: Average loss: 0.0725, Average IOU score: 0.65, Average pixel accuracy: 0.88
#
# Train Epoch: 43 [3/27 (11%)]	Loss: 0.099176
# Train Epoch: 43 [6/27 (22%)]	Loss: 0.106011
# Train Epoch: 43 [9/27 (33%)]	Loss: 0.103508
# Train Epoch: 43 [12/27 (44%)]	Loss: 0.084051
# Train Epoch: 43 [15/27 (56%)]	Loss: 0.087807
# Train Epoch: 43 [18/27 (67%)]	Loss: 0.082074
# Train Epoch: 43 [21/27 (78%)]	Loss: 0.063477
# Train Epoch: 43 [24/27 (89%)]	Loss: 0.071140
# Train Epoch: 43 [27/27 (100%)]	Loss: 0.101587
#
# Validation set: Average loss: 0.1213, Average IOU score: 0.69, Average pixel accuracy: 0.87
#
# Train Epoch: 44 [3/27 (11%)]	Loss: 0.083462
# Train Epoch: 44 [6/27 (22%)]	Loss: 0.084345
# Train Epoch: 44 [9/27 (33%)]	Loss: 0.104428
# Train Epoch: 44 [12/27 (44%)]	Loss: 0.099621
# Train Epoch: 44 [15/27 (56%)]	Loss: 0.108003
# Train Epoch: 44 [18/27 (67%)]	Loss: 0.076888
# Train Epoch: 44 [21/27 (78%)]	Loss: 0.076872
# Train Epoch: 44 [24/27 (89%)]	Loss: 0.111674
# Train Epoch: 44 [27/27 (100%)]	Loss: 0.093180
#
# Validation set: Average loss: 0.0956, Average IOU score: 0.73, Average pixel accuracy: 0.90
#
# Train Epoch: 45 [3/27 (11%)]	Loss: 0.071177
# Train Epoch: 45 [6/27 (22%)]	Loss: 0.105344
# Train Epoch: 45 [9/27 (33%)]	Loss: 0.114470
# Train Epoch: 45 [12/27 (44%)]	Loss: 0.051454
# Train Epoch: 45 [15/27 (56%)]	Loss: 0.077027
# Train Epoch: 45 [18/27 (67%)]	Loss: 0.073475
# Train Epoch: 45 [21/27 (78%)]	Loss: 0.097123
# Train Epoch: 45 [24/27 (89%)]	Loss: 0.105564
# Train Epoch: 45 [27/27 (100%)]	Loss: 0.102488
#
# Validation set: Average loss: 0.0907, Average IOU score: 0.71, Average pixel accuracy: 0.89
#
# Train Epoch: 46 [3/27 (11%)]	Loss: 0.082122
# Train Epoch: 46 [6/27 (22%)]	Loss: 0.094788
# Train Epoch: 46 [9/27 (33%)]	Loss: 0.073736
# Train Epoch: 46 [12/27 (44%)]	Loss: 0.074442
# Train Epoch: 46 [15/27 (56%)]	Loss: 0.140581
# Train Epoch: 46 [18/27 (67%)]	Loss: 0.081529
# Train Epoch: 46 [21/27 (78%)]	Loss: 0.053438
# Train Epoch: 46 [24/27 (89%)]	Loss: 0.074333
# Train Epoch: 46 [27/27 (100%)]	Loss: 0.097829
#
# Validation set: Average loss: 0.0924, Average IOU score: 0.72, Average pixel accuracy: 0.90
#
# Train Epoch: 47 [3/27 (11%)]	Loss: 0.112965
# Train Epoch: 47 [6/27 (22%)]	Loss: 0.123809
# Train Epoch: 47 [9/27 (33%)]	Loss: 0.102428
# Train Epoch: 47 [12/27 (44%)]	Loss: 0.084227
# Train Epoch: 47 [15/27 (56%)]	Loss: 0.095958
# Train Epoch: 47 [18/27 (67%)]	Loss: 0.047744
# Train Epoch: 47 [21/27 (78%)]	Loss: 0.095684
# Train Epoch: 47 [24/27 (89%)]	Loss: 0.115216
# Train Epoch: 47 [27/27 (100%)]	Loss: 0.068929
#
# Validation set: Average loss: 0.0951, Average IOU score: 0.72, Average pixel accuracy: 0.90
#
# Train Epoch: 48 [3/27 (11%)]	Loss: 0.092665
# Train Epoch: 48 [6/27 (22%)]	Loss: 0.076652
# Train Epoch: 48 [9/27 (33%)]	Loss: 0.081996
# Train Epoch: 48 [12/27 (44%)]	Loss: 0.067952
# Train Epoch: 48 [15/27 (56%)]	Loss: 0.076742
# Train Epoch: 48 [18/27 (67%)]	Loss: 0.070224
# Train Epoch: 48 [21/27 (78%)]	Loss: 0.079031
# Train Epoch: 48 [24/27 (89%)]	Loss: 0.072697
# Train Epoch: 48 [27/27 (100%)]	Loss: 0.104462
#
# Validation set: Average loss: 0.0962, Average IOU score: 0.68, Average pixel accuracy: 0.89
#
# Train Epoch: 49 [3/27 (11%)]	Loss: 0.079710
# Train Epoch: 49 [6/27 (22%)]	Loss: 0.134161
# Train Epoch: 49 [9/27 (33%)]	Loss: 0.101770
# Train Epoch: 49 [12/27 (44%)]	Loss: 0.109237
# Train Epoch: 49 [15/27 (56%)]	Loss: 0.097781
# Train Epoch: 49 [18/27 (67%)]	Loss: 0.050049
# Train Epoch: 49 [21/27 (78%)]	Loss: 0.104071
# Train Epoch: 49 [24/27 (89%)]	Loss: 0.120648
# Train Epoch: 49 [27/27 (100%)]	Loss: 0.107185
#
# Validation set: Average loss: 0.1021, Average IOU score: 0.74, Average pixel accuracy: 0.90
#
# Train Epoch: 50 [3/27 (11%)]	Loss: 0.070754
# Train Epoch: 50 [6/27 (22%)]	Loss: 0.070173
# Train Epoch: 50 [9/27 (33%)]	Loss: 0.076087
# Train Epoch: 50 [12/27 (44%)]	Loss: 0.135519
# Train Epoch: 50 [15/27 (56%)]	Loss: 0.071116
# Train Epoch: 50 [18/27 (67%)]	Loss: 0.109712
# Train Epoch: 50 [21/27 (78%)]	Loss: 0.070904
# Train Epoch: 50 [24/27 (89%)]	Loss: 0.076062
# Train Epoch: 50 [27/27 (100%)]	Loss: 0.050713
#
# Validation set: Average loss: 0.0714, Average IOU score: 0.64, Average pixel accuracy: 0.87
#
# Best IOU: 0.7375199928531329
# Pixel accuracy: 0.8998544216156006

# %% [markdown]
# ### Inference

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.figure(figsize=(20,20))

def predict(image, model):
    """Make prediction on image"""
    mean = 0.495
    std = 0.173
    image_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.Pad(30, padding_mode='reflect')
    ])
    im = image_transform(image)
    im = im.view(1, *im.shape)
    model.eval()
    y_pred = model(im)
    pred = torch.argmax(y_pred, dim=1)[0]
    return pred

def visualize(image, pred, label=None):
    """make visualization"""
    n_plot = 2 if label is None else 3
    fig = plt.figure()
    ax = fig.add_subplot(1, n_plot, 1)
    imgplot = plt.imshow(image)
    ax.set_title('Image')
    ax = fig.add_subplot(1, n_plot, 2)
    imgplot = plt.imshow(pred)
    ax.set_title('Prediction')
    if n_plot > 2:
        ax = fig.add_subplot(1, n_plot, 3)
        imgplot = plt.imshow(label)
        ax.set_title('Ground Truth')
    fig.tight_layout()

    plt.show()



for i in range(2,6):    
    images = io.imread(data_dir+f'/train-volume.tif')
    labels = io.imread(data_dir+f'/train-labels.tif')
    image = images[-i]
    label = labels[-i]

    # load model
    print(pretrained_model_path+f'/UNet50.pt')
    checkpoint = torch.load(pretrained_model_path+f'/UNet50.pt', map_location=torch.device('cpu'))
    model = UNet(2)
    model.load_state_dict(checkpoint['model_state_dict'])
    # make inference
    pred = predict(image, model)

    # if args.visualize:
        # crop images for visualization
    dim = image.shape
    out_size = pred.shape[0]
    cut = (dim[0] - out_size) // 2
    image = image[cut:cut+out_size, cut:cut+out_size]
    label = label[cut:cut+out_size, cut:cut+out_size]
    # visualize result
    visualize(image, pred, label)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch/checkpoints/UNet50.pt
# /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch/checkpoints/UNet50.pt
# /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch/checkpoints/UNet50.pt
# /content/drive/MyDrive/Colab_Notebooks/U-Net/UNet-PyTorch/checkpoints/UNet50.pt
